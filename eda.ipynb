# %%
import pandas as pd

# %%
df = pd.read_csv('data/tourism_data.csv')

# %%
df.head()
# Out:
#    Year      Country ISO3  GDP_Growth_Percent  Tourism_Revenue   Data_Type  \
# 0  2000  Afghanistan  AFG            7.513391     2.379600e+10  Historical
# 1  2001  Afghanistan  AFG            7.905501     3.523000e+09  Historical
# 2  2002  Afghanistan  AFG            1.502181     9.550000e+08  Historical
# 3  2003  Afghanistan  AFG           -2.494842     4.900000e+06  Historical
# 4  2004  Afghanistan  AFG           18.286607     5.540000e+08  Historical
#
#            Source
# 0  World Bank API
# 1  World Bank API
# 2  World Bank API
# 3  World Bank API
# 4  World Bank API

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5590 entries, 0 to 5589
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                5590 non-null   int64
#  1   Country             5590 non-null   object
#  2   ISO3                5590 non-null   object
#  3   GDP_Growth_Percent  5590 non-null   float64
#  4   Tourism_Revenue     5590 non-null   float64
#  5   Data_Type           5590 non-null   object
#  6   Source              5590 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 305.8+ KB

# %%
df.describe()
# Out:
#               Year  GDP_Growth_Percent  Tourism_Revenue
# count  5590.000000         5590.000000     5.590000e+03
# mean   2012.500000            3.260907     4.955645e+09
# std       7.500671            5.901257     1.415284e+10
# min    2000.000000          -54.402093     1.000000e+05
# 25%    2006.000000            1.146415     1.642500e+08
# 50%    2012.500000            3.444371     8.162500e+08
# 75%    2019.000000            5.725260     3.744750e+09
# max    2025.000000           86.826748     2.419840e+11

# %%
df.isna().sum()
# Out:
# Year                  0
# Country               0
# ISO3                  0
# GDP_Growth_Percent    0
# Tourism_Revenue       0
# Data_Type             0
# Source                0
# dtype: int64

# %%
df = df[['Year', 'Country', 'ISO3', 'GDP_Growth_Percent', 'Tourism_Revenue']]

# %%
df.head()
# Out:
#    Year      Country ISO3  GDP_Growth_Percent  Tourism_Revenue
# 0  2000  Afghanistan  AFG            7.513391     2.379600e+10
# 1  2001  Afghanistan  AFG            7.905501     3.523000e+09
# 2  2002  Afghanistan  AFG            1.502181     9.550000e+08
# 3  2003  Afghanistan  AFG           -2.494842     4.900000e+06
# 4  2004  Afghanistan  AFG           18.286607     5.540000e+08

# %%
df['GDP_Growth_Percent'].hist()
# Out:
# <Axes: >

# %%
df['Tourism_Revenue'].hist()
# Out:
# <Axes: >

# %%
df['Country'].nunique()
# Out:
# 215

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[['GDP_Growth_Percent', 'Tourism_Revenue']].corr()
# Out:
#                     GDP_Growth_Percent  Tourism_Revenue
# GDP_Growth_Percent            1.000000        -0.031795
# Tourism_Revenue              -0.031795         1.000000
